# %%
import sys
sys.path.append("/reg/neh/home/yoon82/Software/pysingfel/")

import numpy as np
import matplotlib.pyplot as plt
import h5py as h5
import pysingfel as ps
import time

# %%
# Create a particle object
particle = ps.Particle()

particle.read_pdb('../input/3iyf.pdb', ff='WK')

# Load beam
beam = ps.Beam('../input/exp_chuck.beam') 

# Load and initialize the detector
det = ps.PnccdDetector(geom = '../../lcls_detectors/amo86615/PNCCD::CalibV1/Camp.0:pnCCD.1/geometry/0-end.data', 
                       beam = beam)

# %%
particle.rotate_randomly()
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-24-a14e77ac0518> in <module>()
# ----> 1 particle.rotate_randomly()
#
# /reg/neh/home/haoyuan/Documents/my_repos/pysingfel/pysingfel/particle.pyc in rotate_randomly(self, axis)
#      61         :return: None
#      62         """
# ---> 63         quaternion = get_random_rotation(axis)
#      64         self.rotate(quaternion)
#      65
#
# /reg/neh/home/haoyuan/Documents/my_repos/pysingfel/pysingfel/geometry.py in get_random_rotation(rotation_axis)
#     720     if rotation_axis == 'y':
#     721         u = np.random.random() * 2 * np.pi  # random angle between [0, 2pi]
# --> 722         return euler_to_quaternion(0, u, 0)
#     723     else:
#     724         return special_ortho_group.rvs(3)
#
# /reg/neh/home/haoyuan/Documents/my_repos/pysingfel/pysingfel/geometry.py in euler_to_quaternion(psi, theta, phi)
#     579         cc_is_theta = np.corrcoef(x=r, y=angle_axis_to_rot3d(w, theta))
#     580         cc_is_negtheta = np.corrcoef(x=r, y=angle_axis_to_rot3d(w, -theta))
# --> 581         if cc_is_negtheta > cc_is_theta:
#     582             theta = -theta
#     583         quaternion = np.array(
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
plt.plot(particle.atom_pos[:,0]*1e10,particle.atom_pos[:,1]*1e10,'.'); 
plt.xlabel('Position (Angstrom)')
plt.show()

# %%
plt.plot(particle.atom_pos[:,1]*1e10,particle.atom_pos[:,2]*1e10,'.');
plt.xlabel('Position (Angstrom)')
plt.show()

# %% [markdown]
# # Create a 2D pattern

# %%
tic = time.time()
pattern = det.get_photons(device='gpu', particle=particle)
toc = time.time()
print("It takes {:.2f} seconds to finish the calculation.".format(toc-tic))
# Out:
# It takes 6.77 seconds to finish the calculation.

# %% [markdown]
# # Show the field

# %%
fig = plt.figure(figsize=(10, 8))

plt.imshow(det.assemble_image_stack(pattern),vmin=0, vmax=5)
plt.colorbar()
plt.show()

# %%
import numpy as np

# %%
np.random.rand()
# Out:
# 0.8308026963667677
